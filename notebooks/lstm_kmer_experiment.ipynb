# %%
# === 1) Setup ===
import os, sys, json, random
import numpy as np
import torch

# Paths
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), '..'))
SRC_DIR = os.path.join(PROJECT_ROOT, 'src')
DATA_PATH = os.path.join(PROJECT_ROOT, 'data', 'GCF_000001405.26_GRCh38_genomic.fna.gz')
RES_DIR = os.path.join(PROJECT_ROOT, 'res')

if SRC_DIR not in sys.path:
    sys.path.append(SRC_DIR)

# Imports from project
from prepare_data import extract_chromosomes
from models import MaskedLSTMGenerator, DNAModelTrainer, BaseDNAModel
from tokenizers import KmerTokenizer, NucleotideTokenizer

# Reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed(SEED)

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"PyTorch {torch.__version__} | CUDA: {torch.cuda.is_available()} | Device: {device}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")

os.makedirs(RES_DIR, exist_ok=True)
print(f"Results dir: {RES_DIR}")
